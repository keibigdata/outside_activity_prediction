# %%
import requests 
import pandas as pd
import time

# %%
station_info = pd.read_csv('raw_data/subway_station_csv.csv', encoding='CP949', index_col =False)

# %%
name_list = station_info["name"]

# %%
addr_list = pd.DataFrame(columns=["name", "address"])

# %%
# test code
name = "서울역"
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyALGG7xOXPZ7iO6BiWLm0b890gV7aMGVNQ&l&language=ko&resion=KR"
query = []
query.append('한국 ')
query.append(name)
query.append('역')
query = ''.join(query)

params = {'query': query}
cur_html = requests.get(url, params=params).json()
cur_html["status"] = "not"
if(cur_html["status"]=="OK"):
    addr = cur_html['results'][0]['formatted_address']
    newD = [{'name': name, 'address': addr}]
    newDf = pd.DataFrame(newD)
    addr_list = addr_list.append(newDf, ignore_index=True)
    #addr_list.append({"name":name, "address":addr})
else:
    addr_list = addr_list.append(pd.DataFrame([{"name":name, "address":"err"}]))

# %%
for name in name_list:
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyALGG7xOXPZ7iO6BiWLm0b890gV7aMGVNQ&l&language=ko"
    
    query = []
    query.append('한국 ')
    query.append(name)
    query.append('역')
    query = ''.join(query) 
    
    params = {'query': query}
    cur_html = requests.get(url, params=params).json()
    
    time.sleep(3)
    
    print(cur_html["status"])
    if(cur_html["status"]=="OK"):
        addr = cur_html['results'][0]['formatted_address']
        newD = [{'name': name, 'address': addr}]
        newDf = pd.DataFrame(newD)
        addr_list = addr_list.append(newDf, ignore_index=True)
    else:
        addr_list = addr_list.append(pd.DataFrame([{"name":name, "address":"err"}]), ignore_index=True)
# Out:
# OK
# OK
# OK
# OK
# OK
# ZERO_RESULTS
# ZERO_RESULTS
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# ZERO_RESULTS
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# ZERO_RESULTS
# OK
# OK
# OK
# ZERO_RESULTS
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# ZERO_RESULTS
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK

# %%
print(addr_list)
# Out:
#                          address       name
# 0     대한민국 서울특별시 용산구 동자동 청파로 378        서울역
# 1       대한민국 서울특별시 중구 소공동 지하 101         시청
# 2                     대한민국 서울특별시         종각
# 3         대한민국 서울특별시 종로1.2.3.4가동       종로3가
# 4                     대한민국 서울특별시       종로5가
# 5                            err        동대문
# 6                            err        동대문
# 7                 대한민국 서울특별시 신설동        신설동
# 8            대한민국 서울특별시 동대문구 용두동        제기동
# 9                대한민국 서울특별시 전농1동        청량리
# 10               대한민국 서울특별시 숭인2동        동묘앞
# 11      대한민국 서울특별시 중구 소공동 지하 101         시청
# 12         대한민국 서울특별시 중구 을지로동 42      을지로입구
# 13              대한민국 서울특별시 을지로3가      을지로3가
# 14               대한민국 서울특별시 을지로동      을지로4가
# 15        대한민국 서울특별시 중구 을지로동 279  동대문역사문화공원
# 16           대한민국 서울특별시 동대문구 황학동         신당
# 17                    대한민국 서울특별시       상왕십리
# 18                           err        왕십리
# 19                대한민국 서울특별시 사근동        한양대
# 20             대한민국 서울특별시 성수1가2동         뚝섬
# 21     Tehran, Seoul, 133-120 이란         성수
# 22                대한민국 서울특별시 화양동       건대입구
# 23    대한민국 서울특별시 광진구 자양2동 216-22         구의
# 24   대한민국 서울특별시 광진구 구의3동 강변역로 53         강변
# 25              대한민국 경기도 부천시 소사동       잠실나루
# 26               대한민국 서울특별시 잠실6동         잠실
# 27                대한민국 서울특별시 잠실동         신천
# 28               대한민국 서울특별시 잠실7동      종합운동장
# 29                대한민국 서울특별시 강남구         삼성
# ..                           ...        ...
# 249               대한민국 서울특별시 수궁동         온수
# 250     대한민국 경기도 부천시 원미구 성곡동 길주로        까치울
# 251                 대한민국 부천시 춘의동    부천종합운동장
# 252                 대한민국 부천시 춘의동         춘의
# 253                 대한민국 부천시 중3동        신중동
# 254      대한민국 경기도 부천시 원미구 중동 길주로       부천시청
# 255  대한민국 경기도 부천시 원미구 중동 부천시 보건소         상동
# 256                         대한민국      삼산체육관
# 257              대한민국 인천광역시 갈산2동        굴포천
# 258                   대한민국 인천광역시       부평구청
# 259               대한민국 서울특별시 강동구         암사
# 260               대한민국 서울특별시 강동구         천호
# 261   대한민국 서울특별시 강동구 성내1동 성내로 25       강동구청
# 262                   대한민국 서울특별시       몽촌토성
# 263              대한민국 서울특별시 잠실6동         잠실
# 264              대한민국 서울특별시 송파1동         석촌
# 265                   대한민국 서울특별시         송파
# 266               대한민국 서울특별시 송파구       가락시장
# 267               대한민국 서울특별시 송파구         문정
# 268              대한민국 서울특별시 문정2동         장지
# 269               대한민국 서울특별시 장지동         복정
# 270                 대한민국 성남시 신흥동         산성
# 271                 대한민국 성남시 단대동     남한산성입구
# 272                     대한민국 성남시      단대오거리
# 273                대한민국 성남시 신흥3동         신흥
# 274                대한민국 성남시 신흥1동         수진
# 275                 대한민국 성남시 성남동         모란
# 276               대한민국 서울특별시 잠실동       잠실새내
# 277               대한민국 서울특별시 성북구         보문
# 278              대한민국 서울특별시 갈현1동        연신내
#
# [279 rows x 2 columns]

# %%
addr_list.to_csv("addressList2.csv", index=None)

# %%
station_info2 = pd.read_csv('raw_data/subway_station_csv2.csv', encoding='CP949', index_col =False)

# %%
addr_list2 = pd.DataFrame(columns=["name", "address"])

# %%
# test code
address = "대한민국 서울특별시 용산구 동자동 청파로 378"
name = "서울역"
url = "https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyALGG7xOXPZ7iO6BiWLm0b890gV7aMGVNQ&language=ko&resion=KR"
query = []
query.append(address)
query.append(name)
query.append('역')
query = ' '.join(query)

print(query)

params = {'address': query}
cur_html = requests.get(url, params=params).json()

print(cur_html["status"])
#cur_html["status"] = "not"
if(cur_html["status"]=="OK"):
    addr = cur_html['results'][0]['formatted_address']
    newD = [{'name': name, 'address': addr}]
    newDf = pd.DataFrame(newD)
    print(newDf)
    #addr_list = addr_list.append(newDf, ignore_index=True)
    #addr_list.append({"name":name, "address":addr})
else:
    addr_list = addr_list.append(pd.DataFrame([{"name":name, "address":"err"}]))
# Out:
# 대한민국 서울특별시 용산구 동자동 청파로 378 서울역 역
# OK
#                       address name
# 0  대한민국 서울특별시 용산구 동자동 청파로 378  서울역

# %%
for i in range(0,station_info2.shape[0]):
    name = station_info2["name"][i]
    address = station_info2["address"][i]
    url = "https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyALGG7xOXPZ7iO6BiWLm0b890gV7aMGVNQ&language=ko&resion=KR"

    query = []
    query.append('한국 ')
    query.append(name)
    query.append('역')
    query = ''.join(query) 
    
    params = {'address': query}
    cur_html = requests.get(url, params=params).json()
    
    time.sleep(3)
    
    print(cur_html["status"])
    if(cur_html["status"]=="OK"):
        addr = cur_html['results'][0]['formatted_address']
        newD = [{'name': name, 'address': addr}]
        newDf = pd.DataFrame(newD)
        addr_list2 = addr_list2.append(newDf, ignore_index=True)
    else:
        addr_list2 = addr_list2.append(pd.DataFrame([{"name":name, "address":"err"}]), ignore_index=True)
# Out:
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# O